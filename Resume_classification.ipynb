# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
rdf = pd.read_csv("./Resume_Dataset/Resume/Resume.csv", encoding='ISO-8859-1')

# %%
rdf.head()
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category Unnamed: 4  \
# 0  <div class="fontsize fontface vmargins hmargin...       HR        NaN
# 1  <div class="fontsize fontface vmargins hmargin...       HR        NaN
# 2  <div class="fontsize fontface vmargins hmargin...       HR        NaN
# 3  <div class="fontsize fontface vmargins hmargin...       HR        NaN
# 4  <div class="fontsize fontface vmargins hmargin...       HR        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 159  \
# ...

# %%
rdf.tail()
# Out:
#             ID                                         Resume_str  \
# 3441  99416532           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...
# 3442  24589765           GOVERNMENT RELATIONS, COMMUNICATIONS ...
# 3443  31605080           GEEK SQUAD AGENT         Professional...
# 3444  21190805           PROGRAM DIRECTOR / OFFICE MANAGER    ...
# 3445  37473139           STOREKEEPER II       Professional Sum...
#
#                                             Resume_html  Category Unnamed: 4  \
# 3441  <div class="fontsize fontface vmargins hmargin...  AVIATION        NaN
# 3442  <div class="fontsize fontface vmargins hmargin...  AVIATION        NaN
# 3443  <div class="fontsize fontface vmargins hmargin...  AVIATION        NaN
# 3444  <div class="fontsize fontface vmargins hmargin...  AVIATION        NaN
# 3445  <div class="fontsize fontface vmargins hmargin...  AVIATION        NaN
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 159  \
# ...

# %%
rdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3446 entries, 0 to 3445
# Columns: 169 entries, ID to Unnamed: 168
# dtypes: object(169)
# memory usage: 4.4+ MB

# %%
rdf = rdf.iloc[:, :4]
print(rdf.head())
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %% [markdown]
# # Preprocessing

# %%
rdf = rdf.drop(['ID', 'Resume_html'], axis=1)

# %%
rdf.isna().sum()
# Out:
# Resume_str    732
# Category      911
# dtype: int64

# %%
na_rows = rdf.isna().any(axis=1)

# Display the indices of rows with missing values
missing_value_indices = rdf[na_rows].index.tolist()
print(missing_value_indices)
# Out:
# [94, 159, 333, 495, 496, 497, 499, 501, 503, 505, 507, 509, 511, 512, 561, 597, 704, 813, 1016, 1017, 1018, 1019, 1020, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1034, 1035, 1036, 1128, 1303, 1305, 1307, 1309, 1311, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1321, 1322, 1323, 1324, 1422, 1423, 1424, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1434, 1435, 1436, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1521, 1522, 1523, 1524, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 15
# ...

# %%
for i in missing_value_indices:
    print(rdf.loc[i])
# Out:
# Resume_str             HR SPECIALIST (INFORMATION SYSTEMS)  ...
# Category                                                    NaN
# Name: 94, dtype: object
# Resume_str             MECHANICAL DESIGNER         Summary  ...
# Category                                                    NaN
# Name: 159, dtype: object
# Resume_str             MASTER DATA MANAGER           Experie...
# Category                                                    NaN
# Name: 333, dtype: object
# Resume_str             SENIOR MEMBER SERVICE ADVOCATE       ...
# Category                                                    NaN
# Name: 495, dtype: object
# Resume_str     features and accessories.</li> </ul> </span> ...
# Category                                                    NaN
# Name: 496, dtype: object
# Resume_str    NaN
# Category      NaN
# Name: 497, dtype: object
# Resume_str    NaN
# Category      NaN
# Name: 499, dtype: object
# Resume_str    NaN
# Category      NaN
# Name: 501, dtype: object
# ...

# %% [markdown]
# We will remove the rows with NaN in Resume_str and Category

# %%
na_rows = rdf[['Resume_str', 'Category']].isna().any(axis=1)

# %%
rdf = rdf.drop(rdf[na_rows].index)

# %%
rdf.isna().sum()
# Out:
# Resume_str    0
# Category      0
# dtype: int64

# %%
rdf.shape
# Out:
# (2535, 2)

# %% [markdown]
# We will make seperate columns for heading, Highlights, Experience, Education and skills that are extracted from the Resume_str column and finally dropping the Resume_str column

# %%
rdf = rdf.rename(columns={"Resume_str": "Resume"}, errors="raise")

# %%
rdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2535 entries, 0 to 3445
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Resume    2535 non-null   object
#  1   Category  2535 non-null   object
# dtypes: object(2)
# memory usage: 59.4+ KB

# %%
# Count the occurrences of each category
category_counts = rdf['Category'].value_counts()

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="viridis")

# Set title and labels
plt.title('Counts of Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate labels for better readability if needed

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22504\3306994392.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="viridis")
# C:\Users\HP\AppData\Local\Temp\ipykernel_22504\3306994392.py:15: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
rdf['Category'].value_counts()
# Out:
# Category
# ...
